# %% [markdown]
# Note that this notebook was automatically generated from an RDocumentation page. It depends on the package and the example code whether this code will run without errors. You may need to edit the code to make things work.

# %%
if(!require('readr')) {
    install.packages('readr')
    library('readr')
}
# Out:
# Loading required package: readr

# %%
# Input sources -------------------------------------------------------------
# Read from a path
read_csv(readr_example("mtcars.csv"))
read_csv(readr_example("mtcars.csv.zip"))
read_csv(readr_example("mtcars.csv.bz2"))
if (FALSE) {
# Including remote paths
read_csv("https://github.com/tidyverse/readr/raw/main/inst/extdata/mtcars.csv")
}

# Read from multiple file paths at once
continents <- c("africa", "americas", "asia", "europe", "oceania")
filepaths <- vapply(
  paste0("mini-gapminder-", continents, ".csv"),
  FUN = readr_example,
  FUN.VALUE = character(1)
)
read_csv(filepaths, id = "file")

# Or directly from a string with `I()`
read_csv(I("x,y\n1,2\n3,4"))

# Column selection-----------------------------------------------------------
# Pass column names or indexes directly to select them
read_csv(readr_example("chickens.csv"), col_select = c(chicken, eggs_laid))
read_csv(readr_example("chickens.csv"), col_select = c(1, 3:4))

# Or use the selection helpers
read_csv(
  readr_example("chickens.csv"),
  col_select = c(starts_with("c"), last_col())
)

# You can also rename specific columns
read_csv(
  readr_example("chickens.csv"),
  col_select = c(egg_yield = eggs_laid, everything())
)

# Column types --------------------------------------------------------------
# By default, readr guesses the columns types, looking at `guess_max` rows.
# You can override with a compact specification:
read_csv(I("x,y\n1,2\n3,4"), col_types = "dc")

# Or with a list of column types:
read_csv(I("x,y\n1,2\n3,4"), col_types = list(col_double(), col_character()))

# If there are parsing problems, you get a warning, and can extract
# more details with problems()
y <- read_csv(I("x\n1\n2\nb"), col_types = list(col_double()))
y
problems(y)

# Column names --------------------------------------------------------------
# By default, readr duplicate name repair is noisy
read_csv(I("x,x\n1,2\n3,4"))

# To quiet, set the option that controls verbosity of name repair
withr::with_options(
  list(rlib_name_repair_verbosity = "quiet"),
  read_csv(I("x,x\n1,2\n3,4"))
)

# Or use "minimal" to turn off name repair
read_csv(I("x,x\n1,2\n3,4"), name_repair = "minimal")

# File types ----------------------------------------------------------------
read_csv(I("a,b\n1.0,2.0"))
read_csv2(I("a;b\n1,0;2,0"))
read_tsv(I("a\tb\n1.0\t2.0"))
read_delim(I("a|b\n1.0|2.0"), delim = "|")
# Out:
# Rows: 32 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (11): mpg, cyl, disp, hp, drat, wt, qsec, vs, am, gear, carb
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#    mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# 1  21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# 2  21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# 3  22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# 4  21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# 5  18.7 8   360.0 175 3.15 3.440 17.02 0  0  3    2
# 6  18.1 6   225.0 105 2.76 3.460 20.22 1  0  3    1
# 7  14.3 8   360.0 245 3.21 3.570 15.84 0  0  3    4
# 8  24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# 9  22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# 10 19.2 6   167.6 123 3.92 3.440 18.30 1  0  4    4
# 11 17.8 6   167.6 123 3.92 3.440 18.90 1  0  4    4
# 12 16.4 8   275.8 180 3.07 4.070 17.40 0  0  3    3
# 13 17.3 8   275.8 180 3.07 3.730 17.60 0  0  3    3
# 14 15.2 8   275.8 180 3.07 3.780 18.00 0  0  3    3
# 15 10.4 8   472.0 205 2.93 5.250 17.98 0  0  3    4
# 16 10.4 8   460.0 215 3.00 5.424 17.82 0  0  3    4
# 17 14.7 8   440.0 230 3.23 5.345 17.42 0  0  3    4
# 18 32.4 4    78.7  66 4.08 2.200 19.47 1  1  4    1
# 19 30.4 4    75.7  52 4.93 1.615 18.52 1  1  4    2
# 20 33.9 4    71.1  65 4.22 1.835 19.90 1  1  4    1
# 21 21.5 4   120.1  97 3.70 2.465 20.01 1  0  3    1
# 22 15.5 8   318.0 150 2.76 3.520 16.87 0  0  3    2
# 23 15.2 8   304.0 150 3.15 3.435 17.30 0  0  3    2
# 24 13.3 8   350.0 245 3.73 3.840 15.41 0  0  3    4
# 25 19.2 8   400.0 175 3.08 3.845 17.05 0  0  3    2
# 26 27.3 4    79.0  66 4.08 1.935 18.90 1  1  4    1
# 27 26.0 4   120.3  91 4.43 2.140 16.70 0  1  5    2
# 28 30.4 4    95.1 113 3.77 1.513 16.90 1  1  5    2
# 29 15.8 8   351.0 264 4.22 3.170 14.50 0  1  5    4
# 30 19.7 6   145.0 175 3.62 2.770 15.50 0  1  5    6
# 31 15.0 8   301.0 335 3.54 3.570 14.60 0  1  5    8
# 32 21.4 4   121.0 109 4.11 2.780 18.60 1  1  4    2
# Rows: 32 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (11): mpg, cyl, disp, hp, drat, wt, qsec, vs, am, gear, carb
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#    mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# 1  21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# 2  21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# 3  22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# 4  21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# 5  18.7 8   360.0 175 3.15 3.440 17.02 0  0  3    2
# 6  18.1 6   225.0 105 2.76 3.460 20.22 1  0  3    1
# 7  14.3 8   360.0 245 3.21 3.570 15.84 0  0  3    4
# 8  24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# 9  22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# 10 19.2 6   167.6 123 3.92 3.440 18.30 1  0  4    4
# 11 17.8 6   167.6 123 3.92 3.440 18.90 1  0  4    4
# 12 16.4 8   275.8 180 3.07 4.070 17.40 0  0  3    3
# 13 17.3 8   275.8 180 3.07 3.730 17.60 0  0  3    3
# 14 15.2 8   275.8 180 3.07 3.780 18.00 0  0  3    3
# 15 10.4 8   472.0 205 2.93 5.250 17.98 0  0  3    4
# 16 10.4 8   460.0 215 3.00 5.424 17.82 0  0  3    4
# 17 14.7 8   440.0 230 3.23 5.345 17.42 0  0  3    4
# 18 32.4 4    78.7  66 4.08 2.200 19.47 1  1  4    1
# 19 30.4 4    75.7  52 4.93 1.615 18.52 1  1  4    2
# 20 33.9 4    71.1  65 4.22 1.835 19.90 1  1  4    1
# 21 21.5 4   120.1  97 3.70 2.465 20.01 1  0  3    1
# 22 15.5 8   318.0 150 2.76 3.520 16.87 0  0  3    2
# 23 15.2 8   304.0 150 3.15 3.435 17.30 0  0  3    2
# 24 13.3 8   350.0 245 3.73 3.840 15.41 0  0  3    4
# 25 19.2 8   400.0 175 3.08 3.845 17.05 0  0  3    2
# 26 27.3 4    79.0  66 4.08 1.935 18.90 1  1  4    1
# 27 26.0 4   120.3  91 4.43 2.140 16.70 0  1  5    2
# 28 30.4 4    95.1 113 3.77 1.513 16.90 1  1  5    2
# 29 15.8 8   351.0 264 4.22 3.170 14.50 0  1  5    4
# 30 19.7 6   145.0 175 3.62 2.770 15.50 0  1  5    6
# 31 15.0 8   301.0 335 3.54 3.570 14.60 0  1  5    8
# 32 21.4 4   121.0 109 4.11 2.780 18.60 1  1  4    2
# Rows: 32 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (11): mpg, cyl, disp, hp, drat, wt, qsec, vs, am, gear, carb
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#    mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# 1  21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# 2  21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# 3  22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# 4  21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# 5  18.7 8   360.0 175 3.15 3.440 17.02 0  0  3    2
# 6  18.1 6   225.0 105 2.76 3.460 20.22 1  0  3    1
# 7  14.3 8   360.0 245 3.21 3.570 15.84 0  0  3    4
# 8  24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# 9  22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# 10 19.2 6   167.6 123 3.92 3.440 18.30 1  0  4    4
# 11 17.8 6   167.6 123 3.92 3.440 18.90 1  0  4    4
# 12 16.4 8   275.8 180 3.07 4.070 17.40 0  0  3    3
# 13 17.3 8   275.8 180 3.07 3.730 17.60 0  0  3    3
# 14 15.2 8   275.8 180 3.07 3.780 18.00 0  0  3    3
# 15 10.4 8   472.0 205 2.93 5.250 17.98 0  0  3    4
# 16 10.4 8   460.0 215 3.00 5.424 17.82 0  0  3    4
# 17 14.7 8   440.0 230 3.23 5.345 17.42 0  0  3    4
# 18 32.4 4    78.7  66 4.08 2.200 19.47 1  1  4    1
# 19 30.4 4    75.7  52 4.93 1.615 18.52 1  1  4    2
# 20 33.9 4    71.1  65 4.22 1.835 19.90 1  1  4    1
# 21 21.5 4   120.1  97 3.70 2.465 20.01 1  0  3    1
# 22 15.5 8   318.0 150 2.76 3.520 16.87 0  0  3    2
# 23 15.2 8   304.0 150 3.15 3.435 17.30 0  0  3    2
# 24 13.3 8   350.0 245 3.73 3.840 15.41 0  0  3    4
# 25 19.2 8   400.0 175 3.08 3.845 17.05 0  0  3    2
# 26 27.3 4    79.0  66 4.08 1.935 18.90 1  1  4    1
# 27 26.0 4   120.3  91 4.43 2.140 16.70 0  1  5    2
# 28 30.4 4    95.1 113 3.77 1.513 16.90 1  1  5    2
# 29 15.8 8   351.0 264 4.22 3.170 14.50 0  1  5    4
# 30 19.7 6   145.0 175 3.62 2.770 15.50 0  1  5    6
# 31 15.0 8   301.0 335 3.54 3.570 14.60 0  1  5    8
# 32 21.4 4   121.0 109 4.11 2.780 18.60 1  1  4    2
# Rows: 26 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): country
# dbl (4): year, lifeExp, pop, gdpPercap
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#    file
# 1  /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-africa.csv
# 2  /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-africa.csv
# 3  /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-africa.csv
# 4  /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-africa.csv
# 5  /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-africa.csv
# 6  /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-africa.csv
# 7  /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-americas.csv
# 8  /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-americas.csv
# 9  /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-americas.csv
# 10 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-americas.csv
# 11 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-americas.csv
# 12 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-americas.csv
# 13 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-asia.csv
# 14 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-asia.csv
# 15 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-asia.csv
# 16 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-asia.csv
# 17 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-asia.csv
# 18 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-asia.csv
# 19 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-europe.csv
# 20 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-europe.csv
# 21 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-europe.csv
# 22 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-europe.csv
# 23 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-europe.csv
# 24 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-europe.csv
# 25 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-oceania.csv
# 26 /home/repl/.cache/R/renv/cache/v5/R-4.2/x86_64-pc-linux-gnu/readr/2.1.4/b5047343b3825f37ad9d3b5d89aa1078/readr/extdata/mini-gapminder-oceania.csv
#    country                year lifeExp pop       gdpPercap
# 1  Algeria                1952 43.077    9279525  2449.0082
# 2  Angola                 1952 30.015    4232095  3520.6103
# 3  Benin                  1952 38.223    1738315  1062.7522
# 4  Botswana               1952 47.622     442308   851.2411
# 5  Burkina Faso           1952 31.975    4469979   543.2552
# 6  Burundi                1952 39.031    2445618   339.2965
# 7  Argentina              1952 62.485   17876956  5911.3151
# 8  Bolivia                1952 40.414    2883315  2677.3263
# 9  Brazil                 1952 50.917   56602560  2108.9444
# 10 Canada                 1952 68.750   14785584 11367.1611
# 11 Chile                  1952 54.745    6377619  3939.9788
# 12 Colombia               1952 50.643   12350771  2144.1151
# 13 Afghanistan            1952 28.801    8425333   779.4453
# 14 Bahrain                1952 50.939     120447  9867.0848
# 15 Bangladesh             1952 37.484   46886859   684.2442
# 16 Cambodia               1952 39.417    4693836   368.4693
# 17 China                  1952 44.000  556263527   400.4486
# 18 Hong Kong, China       1952 60.960    2125900  3054.4212
# 19 Albania                1952 55.230    1282697  1601.0561
# 20 Austria                1952 66.800    6927772  6137.0765
# 21 Belgium                1952 68.000    8730405  8343.1051
# 22 Bosnia and Herzegovina 1952 53.820    2791000   973.5332
# 23 Bulgaria               1952 59.600    7274900  2444.2866
# 24 Croatia                1952 61.210    3882229  3119.2365
# 25 Australia              1952 69.120    8691212 10039.5956
# 26 New Zealand            1952 69.390    1994794 10556.5757
# Rows: 2 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (2): x, y
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   x y
# 1 1 2
# 2 3 4
# Rows: 5 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): chicken
# dbl (1): eggs_laid
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   chicken                 eggs_laid
# 1 Foghorn Leghorn          0
# 2 Chicken Little           3
# 3 Ginger                  12
# 4 Camilla the Chicken      7
# 5 Ernie The Giant Chicken  0
# Rows: 5 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): chicken, motto
# dbl (1): eggs_laid
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   chicken                 eggs_laid
# 1 Foghorn Leghorn          0
# 2 Chicken Little           3
# 3 Ginger                  12
# 4 Camilla the Chicken      7
# 5 Ernie The Giant Chicken  0
#   motto
# 1 That's a joke, ah say, that's a joke, son.
# 2 The sky is falling!
# 3 Listen. We'll either die free chickens or we die trying.
# 4 Bawk, buck, ba-gawk.
# 5 Put Captain Solo in the cargo hold.
# Rows: 5 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): chicken, motto
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   chicken
# 1 Foghorn Leghorn
# 2 Chicken Little
# 3 Ginger
# 4 Camilla the Chicken
# 5 Ernie The Giant Chicken
#   motto
# 1 That's a joke, ah say, that's a joke, son.
# 2 The sky is falling!
# 3 Listen. We'll either die free chickens or we die trying.
# 4 Bawk, buck, ba-gawk.
# 5 Put Captain Solo in the cargo hold.
# Rows: 5 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): chicken, sex, motto
# dbl (1): eggs_laid
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   egg_yield chicken                 sex
# 1  0        Foghorn Leghorn         rooster
# 2  3        Chicken Little          hen
# 3 12        Ginger                  hen
# 4  7        Camilla the Chicken     hen
# 5  0        Ernie The Giant Chicken rooster
#   motto
# 1 That's a joke, ah say, that's a joke, son.
# 2 The sky is falling!
# 3 Listen. We'll either die free chickens or we die trying.
# 4 Bawk, buck, ba-gawk.
# 5 Put Captain Solo in the cargo hold.
#   x y
# 1 1 2
# 2 3 4
#   x y
# 1 1 2
# 2 3 4
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
#   x
# 1  1
# 2  2
# 3 NA
#   row col expected actual file
# 1 4   1   a double b      /tmp/Rtmp2G2Nl6/file9d18ff1dab
# New names:
# • `x` -> `x...1`
# • `x` -> `x...2`
# Rows: 2 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (2): x...1, x...2
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   x...1 x...2
# 1 1     2
# 2 3     4
# Rows: 2 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (2): x...1, x...2
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   x...1 x...2
# 1 1     2
# 2 3     4
# Rows: 2 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (2): x, x
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   x x
# 1 1 2
# 2 3 4
# Rows: 1 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (2): a, b
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   a b
# 1 1 2
# ℹ Using "','" as decimal and "'.'" as grouping mark. Use `read_delim()` for more control.
#
# Rows: 1 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ";"
# dbl (2): a, b
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   a b
# 1 1 2
# Rows: 1 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# dbl (2): a, b
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   a b
# 1 1 2
# Rows: 1 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "|"
# dbl (2): a, b
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   a b
# 1 1 2
